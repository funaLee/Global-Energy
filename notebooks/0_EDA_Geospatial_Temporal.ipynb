# %% [markdown]
# # Notebook 0: EDA, Temporal & Geospatial Analysis
#
# **Goals:**
# - Univariate & Bivariate Analysis (Distributions, Correlations).
# - Temporal Trends (Global & Country-level).
# - Geospatial Analysis (Choropleth Maps).
# - Multicollinearity Check (VIF).

# %%
import pandas as pd
import sys
import os

# Add src to path
sys.path.append(os.path.abspath(os.path.join('../src')))
from visualization import plot_distribution, plot_correlation_heatmap, plot_scatter_trend, plot_temporal_trend, plot_choropleth
from preprocessing import load_data

# Load Data
data_path = '../data/raw/global-data-on-sustainable-energy.csv'
df = load_data(data_path)
df.head()
